# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/kartik/Downloads/MaRS - Probiotics.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4651 entries, 0 to 4650
# Columns: 107 entries, topic to description
# dtypes: bool(9), float64(22), int64(29), object(47)
# memory usage: 3.5+ MB

# %%
df['url_unique_profile'].unique()
# Out:
# array(['https://www.linkedin.com/in/jason-vickers-240950a0',
#        'https://www.linkedin.com/in/larissa-mor%C3%A9-29799716',
#        'https://www.linkedin.com/in/j-patricia-kim',
#        'https://www.linkedin.com/in/tanyadsouza',
#        'https://www.linkedin.com/in/lenka-dedinova-6a590881',
#        'https://www.linkedin.com/in/indranil-ray-a774ba8',
#        'https://www.linkedin.com/in/olabiyi-atilola-1990431b',
#        'https://www.linkedin.com/in/yanachen',
#        'https://www.linkedin.com/in/aaron-o-sullivan-09153745',
#        'https://www.linkedin.com/in/taniajohn',
#        'https://www.linkedin.com/in/maria-regina-karim-md-0851b512',
#        'https://www.linkedin.com/in/robin-wang-679a4837',
#        'https://www.linkedin.com/in/deeptirao16',
#        'https://www.linkedin.com/in/kaarinataimisto',
#        'https://www.linkedin.com/in/yang-pan2018',
#        'https://www.linkedin.com/in/nelson-acosta-58177420',
# ...

# %%
obj = {'fullname': 'Elton Mataveia', 'first_name': 'Elton', 'last_name': 'Mataveia', 'location': 'Mozambique', 'connectionDegree': '3', 'url_unique_profile': 'https://www.linkedin.com/in/elton-mataveia-41929b105', 'summary': 'not available', 'positions': [{'type': 'Current', 'title': 'Estagiário ', 'companyName': 'IPAJ', 'companyUrl': 'https://www.linkedin.com/recruiter/search?company=IPAJ&updateSearchHistory=true&decorateHits=true&decorateFacets=false&doFacetCounting=true&resetFacets=false&doResultCaching=false&forceResultFromCache=false&origin=PPSC&doProjectBasedCounting=false&count=10&start=0', 'description': None, 'startDateMonth': 2, 'startDateYear': '2018', 'endDateMonth': None, 'endDateYear': None}], 'education': [{'school': 'Universidade Sao Tomas de Mocambique', 'major': '', 'dateRange': '2012 – 2015'}]}

# %%
obj
# Out:
# {'connectionDegree': '3',
#  'education': [{'dateRange': '2012 – 2015',
#    'major': '',
#    'school': 'Universidade Sao Tomas de Mocambique'}],
#  'first_name': 'Elton',
#  'fullname': 'Elton Mataveia',
#  'last_name': 'Mataveia',
#  'location': 'Mozambique',
#  'positions': [{'companyName': 'IPAJ',
#    'companyUrl': 'https://www.linkedin.com/recruiter/search?company=IPAJ&updateSearchHistory=true&decorateHits=true&decorateFacets=false&doFacetCounting=true&resetFacets=false&doResultCaching=false&forceResultFromCache=false&origin=PPSC&doProjectBasedCounting=false&count=10&start=0',
#    'description': None,
#    'endDateMonth': None,
#    'endDateYear': None,
#    'startDateMonth': 2,
#    'startDateYear': '2018',
#    'title': 'Estagiário ',
#    'type': 'Current'}],
#  'summary': 'not available',
#  'url_unique_profile': 'https://www.linkedin.com/in/elton-mataveia-41929b105'}

# %%
obj['fullname']
# Out:
# 'Elton Mataveia'

# %%
for position in obj['positions']:
    if position['type'] == 'Current':
        title = position['title'] if position['title'] != None else ''
        company = position['companyName'] if position['companyName'] != None else ''
        startDateYear = position['startDateYear'] if position['startDateYear'] != None else 'None'
        endDateYear = position['endDateYear'] if position['endDateYear'] != None else 'Present'
        description = position['description'] if position['description'] != None else ''
        
        print(title + '\n' + company + '\n' + startDateYear + ' - ' + endDateYear + '\n' + description)
        
        
    elif position['type'] == 'Past':
        title = position['title'] if position['title'] != None else ''
        company = position['companyName'] if position['companyName'] != None else ''
        startDateYear = position['startDateYear'] if position['startDateYear'] != None else 'None'
        endDateYear = position['endDateYear'] if position['endDateYear'] != None else 'Present'
        description = position['description'] if position['description'] != None else ''
        
        print(title + '\n' + company + '\n' + startDateYear + ' - ' + endDateYear + '\n' + description)
# Out:
# Estagiário
# IPAJ
# 2018 - Present

# %%
for education in obj['education']:
    print(education['school'] + '\n' + education['major'] + '\n' + education['dateRange'])
# Out:
# Universidade Sao Tomas de Mocambique
#
# 2012 – 2015

# %%
obj['url_unique_profile']
# Out:
# 'https://www.linkedin.com/in/elton-mataveia-41929b105'

# %%
df_s = pd.read_csv('/Users/kartik/Documents/newtonx/git_projects/nx-search-api/sascha_exports.csv')

# %%
df_s
# Out:
#                          Name  \
# 0               Mangesh Joshi
# 1   Lisa (Perlmutter) Kueffel
# 2                Kishan Singh
# 3                  Laura Berg
# 4              John Armbrecht
# 5             Michelle Warvel
# 6               Michael Pelto
# 7                 Rohit Gupta
# 8                Ashish Kumar
# 9               Laura Louthan
# 10       Carrie Brown-Schmidt
# 11          Venkat Srinivasan
# 12               Monica Barry
# 13                   Tim Huff
# 14       Sakthi Kaliyaperumal
# 15                 Dan German
# 16                Gino Filice
# 17                Lee Corkran
# 18                Chuck Cigna
# 19            Kristin Carlson
# 20                  Ai Hiruma
# 21              Johannes Wong
# 22             Elizabeth Shaw
# 23              Cameron Craig
# 24       Senthil Rajamanickam
# 25                 Paul Trieu
# 26              Andrea Carver
# 27          J. David Mitchell
# 28              B. Kate Aydin
# 29              Andrew Latham
# ...
